# %% [markdown]
# <a href="https://colab.research.google.com/github/zazaferjancsik/Data-Analytics-Group-Project/blob/master/Assignment1_CY_allTasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import package

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly) (24.1)

# %% [markdown]
# # Task 1
# import dataset by using pandas

# %%
import pandas as pd

# %%
# import dataset
import os
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# dir to the dataset
base='/content/drive/MyDrive/mammographic_masses_data.csv'
print(base)
# Out:
# /content/drive/MyDrive/mammographic_masses_data.csv

# %%
# import dataset
mydata = pd.read_csv(base)
mydata
# Out:
#       BA   Age  Shape  Margin  Density  Severity
# 0    5.0  67.0    3.0     5.0      3.0         1
# 1    4.0  43.0    1.0     1.0      NaN         1
# 2    5.0  58.0    4.0     5.0      3.0         1
# 3    4.0  28.0    1.0     1.0      3.0         0
# 4    5.0  74.0    1.0     5.0      NaN         1
# ..   ...   ...    ...     ...      ...       ...
# 956  4.0  47.0    2.0     1.0      3.0         0
# 957  4.0  56.0    4.0     5.0      3.0         1
# 958  4.0  64.0    4.0     5.0      3.0         0
# 959  5.0  66.0    4.0     5.0      3.0         1
# 960  4.0  62.0    3.0     3.0      3.0         0
#
# [961 rows x 6 columns]

# %% [markdown]
# # Task 2
# get the dataset on screen

# %% [markdown]
# ## 2.1
# initial look of the dataset with pandas function
# **pd.DataFrame(data=mydata)**: this will show the whole dataset
# **pandas.DataFrame.dtypes**: this return the data type of each column.
# **pandas.DataFrame.info**: prints information about a DataFrame including the index dtype and columns, non-null values and memory usage
# **pandas.DataFrame.describ**e: descriptive statistics include those that summarize the central tendency, dispersion and shape of a dataset’s distribution, excluding NaN values
#
#
#
# <https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.info.html>

# %%
# show all the dataset
# this will be the dataset in pandas DataFrame
df = pd.DataFrame(data=mydata)
df
# Out:
#       BA   Age  Shape  Margin  Density  Severity
# 0    5.0  67.0    3.0     5.0      3.0         1
# 1    4.0  43.0    1.0     1.0      NaN         1
# 2    5.0  58.0    4.0     5.0      3.0         1
# 3    4.0  28.0    1.0     1.0      3.0         0
# 4    5.0  74.0    1.0     5.0      NaN         1
# ..   ...   ...    ...     ...      ...       ...
# 956  4.0  47.0    2.0     1.0      3.0         0
# 957  4.0  56.0    4.0     5.0      3.0         1
# 958  4.0  64.0    4.0     5.0      3.0         0
# 959  5.0  66.0    4.0     5.0      3.0         1
# 960  4.0  62.0    3.0     3.0      3.0         0
#
# [961 rows x 6 columns]

# %%
# get the columns input type
df.dtypes
# Out:
# BA          float64
# Age         float64
# Shape       float64
# Margin      float64
# Density     float64
# Severity      int64
# dtype: object

# %%
# get the information of every columns
# it will count the non-null data of each variables
## ->　if the count are not the same, meaning some value missing
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 961 entries, 0 to 960
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   BA        959 non-null    float64
#  1   Age       956 non-null    float64
#  2   Shape     930 non-null    float64
#  3   Margin    913 non-null    float64
#  4   Density   885 non-null    float64
#  5   Severity  961 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 45.2 KB

# %%
# mean_age = df['Age'].mean()
# mean_age
# descriptive statistics summary
summary = df.describe(include='all')
print(summary)
# Out:
#                BA         Age       Shape      Margin     Density    Severity
# count  959.000000  956.000000  930.000000  913.000000  885.000000  961.000000
# mean     4.300313   55.487448    2.721505    2.796276    2.910734    0.463059
# std      0.683469   14.480131    1.242792    1.566546    0.380444    0.498893
# min      0.000000   18.000000    1.000000    1.000000    1.000000    0.000000
# 25%      4.000000   45.000000    2.000000    1.000000    3.000000    0.000000
# 50%      4.000000   57.000000    3.000000    3.000000    3.000000    0.000000
# 75%      5.000000   66.000000    4.000000    4.000000    3.000000    1.000000
# max      6.000000   96.000000    4.000000    5.000000    4.000000    1.000000

# %%
print(summary['Age'])
# Out:
# count    956.000000
# mean      55.487448
# std       14.480131
# min       18.000000
# 25%       45.000000
# 50%       57.000000
# 75%       66.000000
# max       96.000000
# Name: Age, dtype: float64

# %% [markdown]
# ## 2.2
# **loc function**
# the margin attribute of every instance of the data where the severity is 1.

# %%
df.loc[mydata['Severity']==1]
# Out:
#       BA   Age  Shape  Margin  Density  Severity
# 0    5.0  67.0    3.0     5.0      3.0         1
# 1    4.0  43.0    1.0     1.0      NaN         1
# 2    5.0  58.0    4.0     5.0      3.0         1
# 4    5.0  74.0    1.0     5.0      NaN         1
# 8    5.0  57.0    1.0     5.0      3.0         1
# ..   ...   ...    ...     ...      ...       ...
# 951  5.0  67.0    4.0     5.0      3.0         1
# 952  4.0  68.0    4.0     4.0      3.0         1
# 955  4.0  52.0    4.0     4.0      3.0         1
# 957  4.0  56.0    4.0     5.0      3.0         1
# 959  5.0  66.0    4.0     5.0      3.0         1
#
# [445 rows x 6 columns]

# %%
df.loc[mydata['Severity']==1, 'Margin']
# Out:
# 0      5.0
# 1      1.0
# 2      5.0
# 4      5.0
# 8      5.0
#       ...
# 951    5.0
# 952    4.0
# 955    4.0
# 957    5.0
# 959    5.0
# Name: Margin, Length: 445, dtype: float64

# %% [markdown]
# ## 2.3
# Three visualization

# %%
import plotly
import matplotlib.pyplot as plt

# %%
# first visualization, distribution plots, frequency and the variable
# show the frequency of the certain variable
plt.hist(df['Age'], bins=20,  color='lightblue',  edgecolor='black')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# second visualization, scatterplots
# show the relationship between two varibles
## it could also show the frequency of the certain variables
x = df['Age']
y = df['Density']
plot  = plt.scatter(x, y)
plt.xlabel('Age')
plt.ylabel('Density')
plt.title('Age vs Density')
plt.show()

# %%
# third visualization, boxplot
## it show the statistics value of the variable
df.boxplot(column=['Age'], grid=False)
plt.title('Boxplot of Age')
plt.ylabel('Age')
plt.show()

# %%
# third visualization, boxplot
## it show the statistics value of the variable
df.boxplot(grid=False)
plt.title('Boxplot of Age')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# # Task 3
# **my part. DO ITTTT**
# data cleaning and normalization

# %% [markdown]
# ## 3.1
# clean the missing values

# %%
# drop the row if any NA values are present
# the cleaned dataset called cleaned_df
cleaned_df = df.dropna(axis=0, how='any')
cleaned_df
# Out:
#       BA   Age  Shape  Margin  Density  Severity
# 0    5.0  67.0    3.0     5.0      3.0         1
# 2    5.0  58.0    4.0     5.0      3.0         1
# 3    4.0  28.0    1.0     1.0      3.0         0
# 8    5.0  57.0    1.0     5.0      3.0         1
# 10   5.0  76.0    1.0     4.0      3.0         1
# ..   ...   ...    ...     ...      ...       ...
# 956  4.0  47.0    2.0     1.0      3.0         0
# 957  4.0  56.0    4.0     5.0      3.0         1
# 958  4.0  64.0    4.0     5.0      3.0         0
# 959  5.0  66.0    4.0     5.0      3.0         1
# 960  4.0  62.0    3.0     3.0      3.0         0
#
# [830 rows x 6 columns]

# %%
x = cleaned_df['Age']
y = cleaned_df['Density']
plot  = plt.scatter(x, y)
plt.xlabel('Age')
plt.ylabel('Density')
plt.title('Age vs Density')
plt.show()

# %%
# third visualization, boxplot
## it show the statistics value of the variable
cleaned_df.boxplot(column=['Age'], grid=False)
plt.title('Boxplot of Age')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# ## 3.2
# Look at the data type first. Only age is integer, other data are either orginal or nominal, so age is the only one need to normanlize.
# normalized the Age with the max and min value.

# %%
def normalize(col = cleaned_df['Age']):
    reslut = col.copy()
    max_value = col.max()
    min_value = col.min()
    reslut = (col - min_value) / (max_value - min_value)
    return reslut

# %%
normalize_Age = normalize(col = cleaned_df['Age'])
print(normalize_Age)
# Out:
# 0      0.628205
# 2      0.512821
# 3      0.128205
# 8      0.500000
# 10     0.743590
#          ...
# 956    0.371795
# 957    0.487179
# 958    0.589744
# 959    0.615385
# 960    0.564103
# Name: Age, Length: 830, dtype: float64

# %%
# only normanized the Age
# the 2-dimension distribution, comparing between age and density
# age become between 0-1
x = normalize_Age
y = cleaned_df['Density']
plot  = plt.scatter(x, y)
plt.xlabel('Age')
plt.ylabel('Density')
plt.title('Age vs Density')
plt.show()

# %%
plt.boxplot(normalize_Age)
plt.title('Boxplot of Normalized Age')
plt.ylabel('Normalized Age')
plt.show()

# %% [markdown]
# # Task 4
# dimensionality reduction

# %% [markdown]
# ## 4.1
#
# if we wnat tot predict the severity, which feature/variable should we look at(the importance of each variable)?

# %%
from sklearn.feature_selection import SelectKBest, f_classif
import matplotlib.pyplot as plt

# %% [markdown]
# ### k=5('all')

# %%
# Severity is the target variable, what we want to predict
# seperate the Severity column
X = cleaned_df.drop(columns=['Severity'])
y = cleaned_df['Severity']

# selectKBest select the best features based on the F-score
# k is the number of feature. k=5 is same as k='all', as there are 5 variable in X
# f_classif is the ANOVA F-value between label/feature for classification tasks.
selector = SelectKBest(score_func=f_classif, k='all')
X_new = selector.fit_transform(X, y)

# how much variance in the target variable can be explained by each feature,
# higher scores indicating a stronger relationship (more importance) for predicting the target.
feature_scores = selector.scores_
# store result in the dataframe
scores_table = pd.DataFrame({
    'Feature': X.columns,
    'ANOVA F-Score': feature_scores
})
print(scores_table)

# make the bar plot
features = X.columns
plt.bar(features, feature_scores, color='lightblue')
plt.title('Feature Importance based on ANOVA F-value')
plt.xlabel('Features')
plt.ylabel('F-Value Score')

plt.show()
# Out:
#    Feature  ANOVA F-Score
# 0       BA     358.512018
# 1      Age     216.427503
# 2    Shape     387.782271
# 3   Margin     407.908580
# 4  Density       3.920754

# %% [markdown]
# ### k=2

# %%
X = cleaned_df.drop(columns=['Severity'])
y = cleaned_df['Severity']

## the only difference is make k=2
# meaning only selects best 2 feature (two variables with the highest score)
selector_top2 = SelectKBest(score_func=f_classif, k=2)
X_new =selector_top2.fit_transform(X, y)

# Get the mask of the selected features
selected_mask = selector_top2.get_support()
# print out which variable has been selected
variable_table = pd.DataFrame({
    'Feature': X.columns,
    'selected': selected_mask
})
print(variable_table)

# Get the feature scores of all features
feature_scores = selector_top2.scores_
# the scores table with only 2 feature
top_scores_table = pd.DataFrame({
    'Feature': X.columns,
    'ANOVA F-Score': feature_scores
})
# show DataFrame with only the top k=2 features
# only output data where selected_mask = TRUE
top_features = top_scores_table[selected_mask]

# Print the scores of only the top 2 features
print(top_features)

# Plot the scores of only the top 2 features
plt.bar(top_features['Feature'], top_features['ANOVA F-Score'], color='lightblue')
plt.title('Top 2 Feature Importance based on ANOVA F-value')
plt.xlabel('Features')
plt.ylabel('F-Value Score')

plt.show()
# Out:
#    Feature  selected
# 0       BA     False
# 1      Age     False
# 2    Shape      True
# 3   Margin      True
# 4  Density     False
#   Feature  ANOVA F-Score
# 2   Shape     387.782271
# 3  Margin     407.908580

# %% [markdown]
# ## 4.2
# PCA, component reduction.
# since the first two componenet could explain 99.57% of the total variance, we could just set n_component=2. It also could connect to 4.1, like why we finally decide to set k=2 insead of k='all', or why we think k=2 and n_component=2 will be the better choice

# %% [markdown]
# ### k=5, n_components=5

# %%
from sklearn.decomposition import PCA
import matplotlib.patches as mpatches

# Same as 4.1
# Severity is the target variable, what we want to predict
# seperate the Severity column
X = cleaned_df.drop(columns=['Severity'])
y = cleaned_df['Severity']

# apply PCA with n_components=5
pca = PCA(n_components=5)
X_pca = pca.fit_transform(X)

# create a DataFrame with PCA components
pca_df = pd.DataFrame(data=X_pca, columns=[f'Principal Component {i}' for i in range(1, 6)])
# print(pca_df)

# print the explained variance ratio
## the sum will be 1.0, meaning all the component explain total variance
explained_variance = pca.explained_variance_ratio_
print("Explained Variance Ratio:", explained_variance)

# barplot the explained variance
plt.bar([f'PC {i}' for i in range(1, 6)],
        explained_variance, color='lightblue')
plt.title('Explained Variance by Principal Components')
plt.xlabel('Principal Components')
plt.ylabel('Explained Variance Ratio')
plt.show()

# visualize the PCA result in the first two principal components
# because the first two components explain most of the variance, 99.57%
# c stand for color, since there are only two condition of Severity(y) so set two color to easier visualize
colors = ['red' if label == 0 else 'purple' for label in y]
plt.scatter(x=pca_df['Principal Component 1'], y=pca_df['Principal Component 2'],
            c=colors)
plt.title('Principal Components 1 vs 2')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
# Create legend
Benign = mpatches.Patch(color='red', label='Severity=0 (Benign)')
Mailgnant = mpatches.Patch(color='purple', label='Severity=1(Mailgnant)')
# Add the legend to the plot
plt.legend(handles=[Benign, Mailgnant])
plt.show()
# Out:
# Explained Variance Ratio: [9.82524330e-01 1.32145518e-02 2.24661812e-03 1.46435029e-03
#  5.50149740e-04]

# %% [markdown]
# ### k=2, n_components=2

# %%
from sklearn.decomposition import PCA

# Same as 4.1
# Severity is the target variable, what we want to predict
# seperate the Severity column
X = cleaned_df.drop(columns=['Severity'])
y = cleaned_df['Severity']

# apply PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# create a DataFrame with PCA components
pca_df = pd.DataFrame(data=X_pca, columns=['Principal Component 1', 'Principal Component 2'])
# print(pca_df)

# print the explained variance ratio
## the sum will be 1.0 if _components=5, meaning all the component explain total variance
explained_variance = pca.explained_variance_ratio_
print("Explained Variance Ratio:", explained_variance)

# barplot the explained variance
plt.bar(['Principal Component 1', 'Principal Component 2'],
        explained_variance, color='lightblue')
plt.title('Explained Variance by Principal Components')
plt.xlabel('Principal Components')
plt.ylabel('Explained Variance Ratio')
plt.show()

# visualize the PCA result in the first two principal components
# because the first two components explain most of the variance, 99.57%
# c stand for color, since there are only two condition of Severity(y) so set two color to easier visualize
colors = ['red' if label == 0 else 'purple' for label in y]
plt.scatter(x=pca_df['Principal Component 1'], y=pca_df['Principal Component 2'],
            c=colors)
plt.title('Principal Components 1 vs 2')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
# Create legend
Benign = mpatches.Patch(color='red', label='Severity=0 (Benign)')
Mailgnant = mpatches.Patch(color='purple', label='Severity=1(Mailgnant)')
# Add the legend to the plot
plt.legend(handles=[Benign, Mailgnant])
plt.show()
# Out:
# Explained Variance Ratio: [0.98252433 0.01321455]

# %% [markdown]
# ## 4.3
#
# still need to edit this part

# %%
from sklearn.decomposition import TruncatedSVD

# Same as 4.1
# Severity is the target variable, what we want to predict
# seperate the Severity column
X = cleaned_df.drop(columns=['Severity'])
y = cleaned_df['Severity']

# apply Truncated SVD to reduce the dimensionality to 2 components
# the reason of n_components=2 is same as 4.2
svd = TruncatedSVD(n_components=2)
X_svd = svd.fit_transform(X)

# create a DataFrame to store the results
svd_df = pd.DataFrame(X_svd, columns=['Component 1', 'Component 2'])
# add the target variable back for analysis
svd_df['Severity'] = y

# scatter plot of the results with 2 components
# c stand for color, since there are only two condition of Severity(y) so set two color to easier visualize
colors = ['red' if label == 0 else 'purple' for label in svd_df['Severity'] ]
plt.scatter(svd_df['Component 1'], svd_df['Component 2'],
            c=colors)
plt.title('Truncated SVD: Components 1 vs 2')
plt.xlabel('Component 1')
plt.ylabel('Component 2')
# Create legend
Benign = mpatches.Patch(color='red', label='Severity=0 (Benign)')
Mailgnant = mpatches.Patch(color='purple', label='Severity=1(Mailgnant)')
# Add the legend to the plot
plt.legend(handles=[Benign, Mailgnant])
plt.show()

# Show the explained variance ratio for each component
explained_variance = svd.explained_variance_ratio_
explained_variance_df = pd.DataFrame({
    'Component': ['Component 1', 'Component 2'],
    'Explained Variance': explained_variance
})
# Print table of explained variance
print(explained_variance_df)

# Bar plot to show the explained variance ratio of each component
plt.bar(['Component 1', 'Component 2'], explained_variance, color='lightgreen')
plt.title('Explained Variance by SVD Components')
plt.xlabel('Components')
plt.ylabel('Explained Variance Ratio')
plt.show()
# Out:
#      Component  Explained Variance
# 0  Component 1            0.976741
# 1  Component 2            0.014081
